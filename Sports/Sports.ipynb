# %% [markdown]
# **Name - Supriyo Pal**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv('/content/deliveries.csv')
deliveries=df1

# %%
deliveries.head()
# Out:
#    match_id  inning  ... dismissal_kind fielder
# 0         1       1  ...            NaN     NaN
# 1         1       1  ...            NaN     NaN
# 2         1       1  ...            NaN     NaN
# 3         1       1  ...            NaN     NaN
# 4         1       1  ...            NaN     NaN
#
# [5 rows x 21 columns]

# %%
deliveries.shape
# Out:
# (144545, 21)

# %%
deliveries.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     1
# batsman                  1
# non_striker              1
# bowler                   1
# is_super_over            1
# wide_runs                1
# bye_runs                 1
# legbye_runs              1
# noball_runs              1
# penalty_runs             1
# batsman_runs             1
# extra_runs               1
# total_runs               1
# player_dismissed    137400
# dismissal_kind      137400
# fielder             139396
# dtype: int64

# %%
deliveries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144545 entries, 0 to 144544
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          144545 non-null  int64
#  1   inning            144545 non-null  int64
#  2   batting_team      144545 non-null  object
#  3   bowling_team      144545 non-null  object
#  4   over              144545 non-null  int64
#  5   ball              144544 non-null  float64
#  6   batsman           144544 non-null  object
#  7   non_striker       144544 non-null  object
#  8   bowler            144544 non-null  object
#  9   is_super_over     144544 non-null  float64
#  10  wide_runs         144544 non-null  float64
#  11  bye_runs          144544 non-null  float64
#  12  legbye_runs       144544 non-null  float64
#  13  noball_runs       144544 non-null  float64
#  14  penalty_runs      144544 non-null  float64
# ...

# %%
deliveries.describe()
# Out:
#             match_id         inning  ...     extra_runs     total_runs
# count  144545.000000  144545.000000  ...  144544.000000  144544.000000
# mean      305.779038       1.482092  ...       0.069259       1.289379
# std       175.682032       0.501850  ...       0.350248       1.581227
# min         1.000000       1.000000  ...       0.000000       0.000000
# 25%       155.000000       1.000000  ...       0.000000       0.000000
# 50%       307.000000       1.000000  ...       0.000000       1.000000
# 75%       457.000000       2.000000  ...       0.000000       1.000000
# max       611.000000       4.000000  ...       7.000000       7.000000
#
# [8 rows x 13 columns]

# %%
df2=pd.read_csv('/content/matches.csv')
matches=df2

# %%
matches.head()
# Out:
#    id  season       city  ...         umpire1        umpire2 umpire3
# 0   1    2017  Hyderabad  ...     AY Dandekar       NJ Llong     NaN
# 1   2    2017       Pune  ...  A Nand Kishore         S Ravi     NaN
# 2   3    2017     Rajkot  ...     Nitin Menon      CK Nandan     NaN
# 3   4    2017     Indore  ...    AK Chaudhary  C Shamshuddin     NaN
# 4   5    2017  Bangalore  ...             NaN            NaN     NaN
#
# [5 rows x 18 columns]

# %%
matches.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
matches.shape
# Out:
# (756, 18)

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
matches.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
merge = pd.merge(deliveries,matches, left_on='match_id', right_on ='id')
copy_merge=merge
copy_merge.head(2)
# Out:
#    match_id  inning         batting_team  ...      umpire1   umpire2  umpire3
# 0         1       1  Sunrisers Hyderabad  ...  AY Dandekar  NJ Llong      NaN
# 1         1       1  Sunrisers Hyderabad  ...  AY Dandekar  NJ Llong      NaN
#
# [2 rows x 39 columns]

# %%
copy_merge['season']
# Out:
# 0         2017
# 1         2017
# 2         2017
# 3         2017
# 4         2017
#           ...
# 144540    2016
# 144541    2016
# 144542    2016
# 144543    2016
# 144544    2016
# Name: season, Length: 144545, dtype: int64

# %%
copy_merge.corr()
# Out:
#                 match_id    inning  ...  win_by_runs  win_by_wickets
# match_id        1.000000  0.000823  ...    -0.023900       -0.013340
# inning          0.000823  1.000000  ...     0.000132       -0.026609
# over            0.005558 -0.050891  ...     0.006267       -0.042191
# ball           -0.002253 -0.003842  ...     0.001233       -0.001905
# is_super_over   0.000389  0.093756  ...    -0.014032       -0.022849
# wide_runs      -0.004581  0.000043  ...     0.000640        0.006814
# bye_runs       -0.003604 -0.000433  ...     0.001344       -0.004852
# legbye_runs    -0.004649 -0.001890  ...     0.005733       -0.007158
# noball_runs    -0.005311 -0.000031  ...     0.002180       -0.001562
# penalty_runs   -0.000768  0.003839  ...    -0.002204        0.004647
# batsman_runs    0.004160 -0.005253  ...     0.003716       -0.008366
# extra_runs     -0.008363 -0.000994  ...     0.004530       -0.000764
# total_runs      0.002338 -0.005511  ...     0.004746       -0.008595
# ...

# %%
plt.figure(figsize=(10,5))
sns.heatmap(copy_merge.corr())

# %%
copy_merge[copy_merge.city.isnull()][['city','venue']]
# Out:
#        city                                venue
# 109377  NaN  Dubai International Cricket Stadium
# 109378  NaN  Dubai International Cricket Stadium
# 109379  NaN  Dubai International Cricket Stadium
# 109380  NaN  Dubai International Cricket Stadium
# 109381  NaN  Dubai International Cricket Stadium
# ...     ...                                  ...
# 113170  NaN  Dubai International Cricket Stadium
# 113171  NaN  Dubai International Cricket Stadium
# 113172  NaN  Dubai International Cricket Stadium
# 113173  NaN  Dubai International Cricket Stadium
# 113174  NaN  Dubai International Cricket Stadium
#
# [1700 rows x 2 columns]

# %%
copy_merge.city = copy_merge.city.fillna('Dubai')

# %%
copy_merge[copy_merge.city.isnull()][['city','venue']]
# Out:
# Empty DataFrame
# Columns: [city, venue]
# Index: []

# %%
copy_merge[(copy_merge.umpire1.isnull()) | (copy_merge.umpire2.isnull())]
# Out:
#       match_id  inning                 batting_team  ... umpire1  umpire2  umpire3
# 960          5       1  Royal Challengers Bangalore  ...     NaN      NaN      NaN
# 961          5       1  Royal Challengers Bangalore  ...     NaN      NaN      NaN
# 962          5       1  Royal Challengers Bangalore  ...     NaN      NaN      NaN
# 963          5       1  Royal Challengers Bangalore  ...     NaN      NaN      NaN
# 964          5       1  Royal Challengers Bangalore  ...     NaN      NaN      NaN
# ...        ...     ...                          ...  ...     ...      ...      ...
# 1203         5       2             Delhi Daredevils  ...     NaN      NaN      NaN
# 1204         5       2             Delhi Daredevils  ...     NaN      NaN      NaN
# 1205         5       2             Delhi Daredevils  ...     NaN      NaN      NaN
# 1206         5       2             Delhi Daredevils  ...     NaN      NaN      NaN
# ...

# %%
copy_merge['umpire1'].isnull().sum()
# Out:
# 248

# %%
copy_merge['umpire2'].isnull().sum()
# Out:
# 248

# %%
copy_merge['umpire3'].isnull().sum()
# Out:
# 144545

# %%
copy_merge.drop(['umpire3'],inplace=True,axis=1)

# %%
city_vanues=copy_merge.groupby(['city','venue']).count()['season']

# %%
pd.DataFrame(city_vanues)
# Out:
#                                                                    season
# city           venue
# Abu Dhabi      Sheikh Zayed Stadium                                  1624
# Ahmedabad      Sardar Patel Stadium, Motera                          2893
# Bangalore      M Chinnaswamy Stadium                                13868
# Bloemfontein   OUTsurance Oval                                        500
# Cape Town      Newlands                                              1539
# Centurion      SuperSport Park                                       2866
# Chandigarh     Punjab Cricket Association IS Bindra Stadium, M...    1840
#                Punjab Cricket Association Stadium, Mohali            8266
# Chennai        MA Chidambaram Stadium, Chepauk                      11760
# Cuttack        Barabati Stadium                                      1695
# Delhi          Feroz Shah Kotla                                     13464
# ...

# %%
v = pd.crosstab(copy_merge['city'],copy_merge['venue'])
v
# Out:
# venue           Barabati Stadium  ...  Wankhede Stadium
# city                              ...
# Abu Dhabi                      0  ...                 0
# Ahmedabad                      0  ...                 0
# Bangalore                      0  ...                 0
# Bloemfontein                   0  ...                 0
# Cape Town                      0  ...                 0
# Centurion                      0  ...                 0
# Chandigarh                     0  ...                 0
# Chennai                        0  ...                 0
# Cuttack                     1695  ...                 0
# Delhi                          0  ...                 0
# Dharamsala                     0  ...                 0
# Dubai                          0  ...                 0
# Durban                         0  ...                 0
# East London                    0  ...                 0
# Hyderabad                      0  ...                 0
# ...

# %%
v['count']=v.sum(axis='columns')
p=v['count']
plt.figure(figsize=(15,10))
plt.title('Number of times games played in different cities',fontsize=20)
plt.xlabel("City",fontsize=15)
plt.ylabel("Freequency",fontsize=15)
p.plot(kind='bar')

# %%
copy_merge['season']
# Out:
# 0         2017
# 1         2017
# 2         2017
# 3         2017
# 4         2017
#           ...
# 144540    2016
# 144541    2016
# 144542    2016
# 144543    2016
# 144544    2016
# Name: season, Length: 144545, dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.countplot('season',data=copy_merge)
plt.title("Seasons in different Years")
plt.xlabel("Season")
plt.ylabel("Count")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize=(15,5))
plt.title(" Number of Teams played in each season")
copy_merge.groupby('season')['team1'].nunique().plot(kind='bar')

# %%
wining_teams=copy_merge[['season','winner']]
wining_teams
# Out:
#         season                       winner
# 0         2017          Sunrisers Hyderabad
# 1         2017          Sunrisers Hyderabad
# 2         2017          Sunrisers Hyderabad
# 3         2017          Sunrisers Hyderabad
# 4         2017          Sunrisers Hyderabad
# ...        ...                          ...
# 144540    2016  Royal Challengers Bangalore
# 144541    2016  Royal Challengers Bangalore
# 144542    2016  Royal Challengers Bangalore
# 144543    2016  Royal Challengers Bangalore
# 144544    2016  Royal Challengers Bangalore
#
# [144545 rows x 2 columns]

# %%
plt.figure(figsize=(15,5))
plt.title(" Wining List of different teams")

copy_merge.groupby('winner')['season'].nunique().plot(kind='bar',)

# %%
wining=copy_merge.groupby('winner')['season'].nunique()
wining
# Out:
# winner
# Chennai Super Kings             8
# Deccan Chargers                 5
# Delhi Daredevils               10
# Gujarat Lions                   2
# Kings XI Punjab                10
# Kochi Tuskers Kerala            1
# Kolkata Knight Riders          10
# Mumbai Indians                 10
# Pune Warriors                   3
# Rajasthan Royals                8
# Rising Pune Supergiant          1
# Rising Pune Supergiants         1
# Royal Challengers Bangalore    10
# Sunrisers Hyderabad             5
# Name: season, dtype: int64

# %%
copy_merge['toss_decision'].value_counts().plot(kind='pie', fontsize=14, autopct='%3.1f%%', 
                                               figsize=(10,7), shadow=True, startangle=135, legend=True, cmap='Oranges')
plt.ylabel('Toss Decision')
plt.title('Decision taken by captains after winning tosses')
# Out:
# Text(0.5, 1.0, 'Decision taken by captains after winning tosses')

# %%
plt.figure(figsize=(15,5))
plt.title(" which team choses batting after wining the toss")
plt.xlabel("Teams")
plt.ylabel("Occourance")
copy_merge['batting_team'].value_counts().plot(kind='bar')

# %%
copy_merge['toss_winner'].value_counts()
# Out:
# Mumbai Indians                 19660
# Kolkata Knight Riders          18159
# Chennai Super Kings            15753
# Delhi Daredevils               15748
# Royal Challengers Bangalore    15567
# Kings XI Punjab                15283
# Rajasthan Royals               15034
# Deccan Chargers                10376
# Sunrisers Hyderabad             7206
# Pune Warriors                   4798
# Gujarat Lions                   2662
# Kochi Tuskers Kerala            1760
# Rising Pune Supergiant          1371
# Rising Pune Supergiants         1168
# Name: toss_winner, dtype: int64

# %%
plt.figure(figsize=(15,5))
plt.title(" Toss Winner Game Winner")
plt.xlabel("Teams")
plt.ylabel("Occourance")
toss_win_game_win=copy_merge.groupby('toss_winner')['winner'].nunique()
toss_win_game_win.plot(kind='bar')

# %%
plt.figure(figsize = (20,10))
sns.countplot('toss_winner', data = matches, hue = 'toss_decision')
plt.title("Teams decision to bat first or second after winning toss", size = 30, fontweight = 'bold')
plt.xticks(x=copy_merge['toss_winner'], rotation='45',size=20)
plt.yticks(size = 15)
plt.xlabel("Toss Winner", size = 35)
plt.ylabel("Count", size = 35)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Count')

# %%
MoM= matches['player_of_match'].value_counts()
MoM.head(10).plot(kind = 'bar',figsize=(12,8), fontsize=15)
plt.title("Top 10 players with most MoM awards",fontsize=18,fontweight="bold")
plt.ylabel("Frequency", size = 25)
plt.xlabel("Players", size = 25)
# Out:
# Text(0.5, 0, 'Players')

# %%
merge.groupby('bowler')['player_dismissed'].count().sort_values(ascending = False).head(10).plot(kind = 'bar',color = 'purple', figsize = (15,5))
plt.title("Top Wicket Takers of IPL", fontsize = 20, fontweight = 'bold')
plt.xlabel("Bowler", size = 25)
plt.ylabel("Total Wickets Taken", size = 25)
plt.xticks(size = 12)
plt.yticks(size = 12)
# Out:
# (array([  0.,  20.,  40.,  60.,  80., 100., 120., 140., 160., 180.]),
#  <a list of 10 Text major ticklabel objects>)
